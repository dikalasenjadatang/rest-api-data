# %%
import pandas as pd
from pymongo import MongoClient

# %%
# MongoDB connection
client = MongoClient('mongodb://localhost:27017/')  # Adjust the connection string as needed
db = client['TESTING']  # Replace with your database name
collection = db['search_result']  # Replace with your collection name

# Load data from MongoDB
document = collection.find_one({'_id': 'youtube'})

# Extract the data part
data = document['data'] if document else []

# Convert to DataFrame
df = pd.DataFrame(data)

df.head()
# Out:
#                  judul                        ringkasan   sumber  \
# 0  New YouTube Video 1  Summary of new YouTube video 1.  YouTube
# 1  New YouTube Video 2  Summary of new YouTube video 2.  YouTube
#
#                 tanggal                                       url label_owner  \
# 0  2024-08-02T03:00:00Z  https://www.youtube.com/watch?v=example1    Personal
# 1  2024-08-02T04:00:00Z  https://www.youtube.com/watch?v=example2    Personal
#
#               label_timestamp
# 0  2024-08-02T11:06:54.074239
# 1  2024-08-02T11:06:54.074239

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#                                                judul  \
# 0  Profil Hetifah Sjaifudian, Anggota DPR RI Dapi...
# 1  Menhub Budi Pede Tol Laut Lanjut di Masa Prabo...
# 2  Sah! Pasangan Salim Fakhry-Heri Al Hilal Maju ...
# 3  Gerindra Kaget Ada Isu Gusur PDIP dari Kursi K...
# 4  KPK Diminta Tindak Lanjuti Laporan Dugaan Koru...
#
#                                            ringkasan  \
# 0  Sebanyak 580 caleg berhasil memastikan diri lo...
# 1  Budi meyakini bahwa program tol laut tidak han...
# 2  KUTACANE, Waspada.co.id - Dewan Pimpinan Pusat...
# 3  WAKIL Ketua DPR RI Sufmi Dasco dari Fraksi Par...
# 4  Liputan6.com, Jakarta Menteri Agama atau Menag...
#
#                               sumber               tanggal  \
# 0                      Tribun Kaltim  2024-08-02T02:53:20Z
# 1                         VIVA.co.id  2024-08-02T02:41:08Z
# 2                     Waspada Online  2024-08-02T02:40:57Z
# 3  Media Indonesia - News & Views -   2024-08-02T02:35:58Z
# 4                          Liputan 6  2024-08-02T02:32:11Z
#
#                                                  url label_owner  \
# 0  https://kaltim.tribunnews.com/2024/08/02/profi...    Personal
# 1  https://www.viva.co.id/bisnis/1738349-menhub-b...    Personal
# 2  https://waspada.co.id/sah-pasangan-salim-fakhr...    Personal
# 3  https://mediaindonesia.com/politik-dan-hukum/6...    Personal
# 4  https://www.liputan6.com/news/read/5661714/kpk...    Personal
#
#               label_timestamp                       _id
# 0  2024-08-02T10:47:40.321627  66ac591ef5bdb359f53e5aa3
# 1  2024-08-02T10:47:40.321627  66ac591ef5bdb359f53e5aa4
# 2  2024-08-02T10:47:40.321627  66ac591ef5bdb359f53e5aa5
# 3  2024-08-02T10:47:40.321627  66ac591ef5bdb359f53e5aa6
# 4  2024-08-02T10:47:40.321627  66ac591ef5bdb359f53e5aa7
